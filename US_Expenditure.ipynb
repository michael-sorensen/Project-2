# %%
import pandas as pd
from sqlalchemy import create_engine
import pprint
import psycopg2

# %%
# Import CSV files
csvfile = "DataFiles/SAEXP1.csv"
us_expenditures = pd.read_csv(csvfile)

# %%
us_expenditures.columns
# Out:
# Index(['GeoFIPS', 'GeoName', 'Region', 'TableName', 'LineCode',
#        'IndustryClassification', 'Description', 'Unit', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019'],
#       dtype='object')

# %%
us_expenditures_df = us_expenditures.melt(id_vars=['GeoName', 'Region','Description'],value_vars=['1997', '1998', '1999',
       '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
       '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
       '2018', '2019'], var_name="Year")
us_expenditures_df
# Out:
#              GeoName Region  \
# 0      United States
# 1      United States
# 2      United States
# 3      United States
# 4      United States
# ...              ...    ...
# 33207       Far West      8
# 33208            NaN    NaN
# 33209            NaN    NaN
# 33210            NaN    NaN
# 33211            NaN    NaN
#
#                                              Description  Year      value
# 0                      Personal consumption expenditures  1997  5534091.8
# 1                                                  Goods  1997  2003807.2
# 2                                          Durable goods  1997   715529.6
# 3                               Motor vehicles and parts  1997   293082.5
# 4            Furnishings and durable household equipment  1997   160490.2
# ...                                                  ...   ...        ...
# 33207     Less: Receipts from sales of goods and serv...  2019   236897.2
# 33208                                                NaN  2019        NaN
# 33209                                                NaN  2019        NaN
# 33210                                                NaN  2019        NaN
# 33211                                                NaN  2019        NaN
#
# [33212 rows x 5 columns]

# %%
#remove NAN rows
us_expend = us_expenditures_df[us_expenditures_df['GeoName'].notna()]
us_expend
# Out:
#              GeoName Region  \
# 0      United States
# 1      United States
# 2      United States
# 3      United States
# 4      United States
# ...              ...    ...
# 33203       Far West      8
# 33204       Far West      8
# 33205       Far West      8
# 33206       Far West      8
# 33207       Far West      8
#
#                                              Description  Year      value
# 0                      Personal consumption expenditures  1997  5534091.8
# 1                                                  Goods  1997  2003807.2
# 2                                          Durable goods  1997   715529.6
# 3                               Motor vehicles and parts  1997   293082.5
# 4            Furnishings and durable household equipment  1997   160490.2
# ...                                                  ...   ...        ...
# 33203                   Financial services and insurance  2019   210726.1
# 33204                                     Other services  2019   220767.1
# 33205    Final consumption expenditures of nonprofit ...  2019    88265.6
# 33206             Gross output of nonprofit institutions  2019   325162.7
# 33207     Less: Receipts from sales of goods and serv...  2019   236897.2
#
# [33120 rows x 5 columns]

# %%
# rename columns
us_expenditures_final = us_expend.rename(columns ={'value':'Dollars'})
us_expenditures_final
# Out:
#              GeoName Region  \
# 0      United States
# 1      United States
# 2      United States
# 3      United States
# 4      United States
# ...              ...    ...
# 33203       Far West      8
# 33204       Far West      8
# 33205       Far West      8
# 33206       Far West      8
# 33207       Far West      8
#
#                                              Description  Year    Dollars
# 0                      Personal consumption expenditures  1997  5534091.8
# 1                                                  Goods  1997  2003807.2
# 2                                          Durable goods  1997   715529.6
# 3                               Motor vehicles and parts  1997   293082.5
# 4            Furnishings and durable household equipment  1997   160490.2
# ...                                                  ...   ...        ...
# 33203                   Financial services and insurance  2019   210726.1
# 33204                                     Other services  2019   220767.1
# 33205    Final consumption expenditures of nonprofit ...  2019    88265.6
# 33206             Gross output of nonprofit institutions  2019   325162.7
# 33207     Less: Receipts from sales of goods and serv...  2019   236897.2
#
# [33120 rows x 5 columns]

# %%
# List of categories - 25 categories
description = us_expenditures_df['Description'].unique()
description
# Out:
# array(['Personal consumption expenditures', ' Goods', '  Durable goods',
#        '   Motor vehicles and parts',
#        '   Furnishings and durable household equipment',
#        '   Recreational goods and vehicles', '   Other durable goods',
#        '  Nondurable goods',
#        '   Food and beverages purchased for off-premises consumption',
#        '   Clothing and footwear', '   Gasoline and other energy goods',
#        '   Other nondurable goods', ' Services',
#        '  Household consumption expenditures (for services)',
#        '   Housing and utilities', '   Health care',
#        '   Transportation services', '   Recreation services',
#        '   Food services and accommodations',
#        '   Financial services and insurance', '   Other services',
#        '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)',
#        '   Gross output of nonprofit institutions',
#        '   Less: Receipts from sales of goods and services by nonprofit institutions',
#        nan], dtype=object)

# %%
#connection = engine.connect()
engine = create_engine('sqlite:///DataFiles/SAEXP1', echo=False)

# %%
# save data into sqlite
us_expenditures_final.to_sql('us_expenditures_final', con=engine, if_exists='replace')

# %%
engine.execute("SELECT * FROM us_expenditures_final").fetchall()
# Out:
# [(0, 'United States', ' ', 'Personal consumption expenditures', '1997', 5534091.8),
#  (1, 'United States', ' ', ' Goods', '1997', 2003807.2),
#  (2, 'United States', ' ', '  Durable goods', '1997', 715529.6),
#  (3, 'United States', ' ', '   Motor vehicles and parts', '1997', 293082.5),
#  (4, 'United States', ' ', '   Furnishings and durable household equipment', '1997', 160490.2),
#  (5, 'United States', ' ', '   Recreational goods and vehicles', '1997', 174632.0),
#  (6, 'United States', ' ', '   Other durable goods', '1997', 87324.8),
#  (7, 'United States', ' ', '  Nondurable goods', '1997', 1288277.7),
#  (8, 'United States', ' ', '   Food and beverages purchased for off-premises consumption', '1997', 474777.2),
#  (9, 'United States', ' ', '   Clothing and footwear', '1997', 247496.1),
#  (10, 'United States', ' ', '   Gasoline and other energy goods', '1997', 147661.2),
#  (11, 'United States', ' ', '   Other nondurable goods', '1997', 418343.1),
#  (12, 'United States', ' ', ' Services', '1997', 3530284.6),
#  (13, 'United States', ' ', '  Household consumption expenditures (for services)', '1997', 3424696.6),
#  (14, 'United States', ' ', '   Housing and utilities', '1997', 1009822.3),
#  (15, 'United States', ' ', '   Health care', '1997', 790947.7),
#  (16, 'United States', ' ', '   Transportation services', '1997', 211803.2),
#  (17, 'United States', ' ', '   Recreation services', '1997', 208317.0),
#  (18, 'United States', ' ', '   Food services and accommodations', '1997', 343427.5),
#  (19, 'United States', ' ', '   Financial services and insurance', '1997', 408884.2),
#  (20, 'United States', ' ', '   Other services', '1997', 451494.8),
#  (21, 'United States', ' ', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 105588.0),
#  (22, 'United States', ' ', '   Gross output of nonprofit institutions', '1997', 502624.5),
#  (23, 'United States', ' ', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 397036.5),
#  (24, 'Alabama', '5', 'Personal consumption expenditures', '1997', 74340.3),
#  (25, 'Alabama', '5', ' Goods', '1997', 30295.9),
#  (26, 'Alabama', '5', '  Durable goods', '1997', 10102.1),
#  (27, 'Alabama', '5', '   Motor vehicles and parts', '1997', 4891.9),
#  (28, 'Alabama', '5', '   Furnishings and durable household equipment', '1997', 2221.4),
#  (29, 'Alabama', '5', '   Recreational goods and vehicles', '1997', 1907.8),
#  (30, 'Alabama', '5', '   Other durable goods', '1997', 1081.0),
#  (31, 'Alabama', '5', '  Nondurable goods', '1997', 20193.8),
#  (32, 'Alabama', '5', '   Food and beverages purchased for off-premises consumption', '1997', 7742.9),
#  (33, 'Alabama', '5', '   Clothing and footwear', '1997', 3549.5),
#  (34, 'Alabama', '5', '   Gasoline and other energy goods', '1997', 2437.2),
#  (35, 'Alabama', '5', '   Other nondurable goods', '1997', 6464.2),
#  (36, 'Alabama', '5', ' Services', '1997', 44044.5),
#  (37, 'Alabama', '5', '  Household consumption expenditures (for services)', '1997', 43244.5),
#  (38, 'Alabama', '5', '   Housing and utilities', '1997', 10965.1),
#  (39, 'Alabama', '5', '   Health care', '1997', 12476.8),
#  (40, 'Alabama', '5', '   Transportation services', '1997', 2098.2),
#  (41, 'Alabama', '5', '   Recreation services', '1997', 3274.5),
#  (42, 'Alabama', '5', '   Food services and accommodations', '1997', 4194.7),
#  (43, 'Alabama', '5', '   Financial services and insurance', '1997', 4754.1),
#  (44, 'Alabama', '5', '   Other services', '1997', 5481.2),
#  (45, 'Alabama', '5', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 800.0),
#  (46, 'Alabama', '5', '   Gross output of nonprofit institutions', '1997', 6320.0),
#  (47, 'Alabama', '5', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 5520.0),
#  (48, 'Alaska', '8', 'Personal consumption expenditures', '1997', 13799.3),
#  (49, 'Alaska', '8', ' Goods', '1997', 5120.5),
#  (50, 'Alaska', '8', '  Durable goods', '1997', 1685.2),
#  (51, 'Alaska', '8', '   Motor vehicles and parts', '1997', 573.7),
#  (52, 'Alaska', '8', '   Furnishings and durable household equipment', '1997', 361.5),
#  (53, 'Alaska', '8', '   Recreational goods and vehicles', '1997', 524.0),
#  (54, 'Alaska', '8', '   Other durable goods', '1997', 226.0),
#  (55, 'Alaska', '8', '  Nondurable goods', '1997', 3435.3),
#  (56, 'Alaska', '8', '   Food and beverages purchased for off-premises consumption', '1997', 1463.2),
#  (57, 'Alaska', '8', '   Clothing and footwear', '1997', 513.5),
#  (58, 'Alaska', '8', '   Gasoline and other energy goods', '1997', 466.5),
#  (59, 'Alaska', '8', '   Other nondurable goods', '1997', 992.1),
#  (60, 'Alaska', '8', ' Services', '1997', 8678.8),
#  (61, 'Alaska', '8', '  Household consumption expenditures (for services)', '1997', 8247.8),
#  (62, 'Alaska', '8', '   Housing and utilities', '1997', 2348.8),
#  (63, 'Alaska', '8', '   Health care', '1997', 1719.0),
#  (64, 'Alaska', '8', '   Transportation services', '1997', 452.7),
#  (65, 'Alaska', '8', '   Recreation services', '1997', 390.0),
#  (66, 'Alaska', '8', '   Food services and accommodations', '1997', 1089.1),
#  (67, 'Alaska', '8', '   Financial services and insurance', '1997', 1022.8),
#  (68, 'Alaska', '8', '   Other services', '1997', 1225.4),
#  (69, 'Alaska', '8', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 431.0),
#  (70, 'Alaska', '8', '   Gross output of nonprofit institutions', '1997', 1396.0),
#  (71, 'Alaska', '8', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 965.0),
#  (72, 'Arizona', '6', 'Personal consumption expenditures', '1997', 91972.3),
#  (73, 'Arizona', '6', ' Goods', '1997', 34461.2),
#  (74, 'Arizona', '6', '  Durable goods', '1997', 12853.7),
#  (75, 'Arizona', '6', '   Motor vehicles and parts', '1997', 5311.8),
#  (76, 'Arizona', '6', '   Furnishings and durable household equipment', '1997', 3055.6),
#  (77, 'Arizona', '6', '   Recreational goods and vehicles', '1997', 2926.6),
#  (78, 'Arizona', '6', '   Other durable goods', '1997', 1559.6),
#  (79, 'Arizona', '6', '  Nondurable goods', '1997', 21607.6),
#  (80, 'Arizona', '6', '   Food and beverages purchased for off-premises consumption', '1997', 8129.8),
#  (81, 'Arizona', '6', '   Clothing and footwear', '1997', 3623.1),
#  (82, 'Arizona', '6', '   Gasoline and other energy goods', '1997', 2940.9),
#  (83, 'Arizona', '6', '   Other nondurable goods', '1997', 6913.7),
#  (84, 'Arizona', '6', ' Services', '1997', 57511.0),
#  (85, 'Arizona', '6', '  Household consumption expenditures (for services)', '1997', 56580.0),
#  (86, 'Arizona', '6', '   Housing and utilities', '1997', 16631.7),
#  (87, 'Arizona', '6', '   Health care', '1997', 11336.2),
#  (88, 'Arizona', '6', '   Transportation services', '1997', 3516.3),
#  (89, 'Arizona', '6', '   Recreation services', '1997', 3381.1),
#  (90, 'Arizona', '6', '   Food services and accommodations', '1997', 6740.4),
#  (91, 'Arizona', '6', '   Financial services and insurance', '1997', 8506.5),
#  (92, 'Arizona', '6', '   Other services', '1997', 6467.9),
#  (93, 'Arizona', '6', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 931.0),
#  (94, 'Arizona', '6', '   Gross output of nonprofit institutions', '1997', 6409.0),
#  (95, 'Arizona', '6', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 5478.0),
#  (96, 'Arkansas', '5', 'Personal consumption expenditures', '1997', 41057.2),
#  (97, 'Arkansas', '5', ' Goods', '1997', 17170.9),
#  (98, 'Arkansas', '5', '  Durable goods', '1997', 5942.9),
#  (99, 'Arkansas', '5', '   Motor vehicles and parts', '1997', 2737.8),
#  (100, 'Arkansas', '5', '   Furnishings and durable household equipment', '1997', 1310.1),
#  (101, 'Arkansas', '5', '   Recreational goods and vehicles', '1997', 1105.9),
#  (102, 'Arkansas', '5', '   Other durable goods', '1997', 789.1),
#  (103, 'Arkansas', '5', '  Nondurable goods', '1997', 11228.0),
#  (104, 'Arkansas', '5', '   Food and beverages purchased for off-premises consumption', '1997', 3949.3),
#  (105, 'Arkansas', '5', '   Clothing and footwear', '1997', 2039.8),
#  (106, 'Arkansas', '5', '   Gasoline and other energy goods', '1997', 1635.6),
#  (107, 'Arkansas', '5', '   Other nondurable goods', '1997', 3603.2),
#  (108, 'Arkansas', '5', ' Services', '1997', 23886.3),
#  (109, 'Arkansas', '5', '  Household consumption expenditures (for services)', '1997', 23424.3),
#  (110, 'Arkansas', '5', '   Housing and utilities', '1997', 6623.9),
#  (111, 'Arkansas', '5', '   Health care', '1997', 6555.4),
#  (112, 'Arkansas', '5', '   Transportation services', '1997', 1128.3),
#  (113, 'Arkansas', '5', '   Recreation services', '1997', 1136.7),
#  (114, 'Arkansas', '5', '   Food services and accommodations', '1997', 2352.6),
#  (115, 'Arkansas', '5', '   Financial services and insurance', '1997', 2784.4),
#  (116, 'Arkansas', '5', '   Other services', '1997', 2842.9),
#  (117, 'Arkansas', '5', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 462.0),
#  (118, 'Arkansas', '5', '   Gross output of nonprofit institutions', '1997', 3305.0),
#  (119, 'Arkansas', '5', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 2843.0),
#  (120, 'California', '8', 'Personal consumption expenditures', '1997', 689108.2),
#  (121, 'California', '8', ' Goods', '1997', 223057.6),
#  (122, 'California', '8', '  Durable goods', '1997', 81204.9),
#  (123, 'California', '8', '   Motor vehicles and parts', '1997', 28054.6),
#  (124, 'California', '8', '   Furnishings and durable household equipment', '1997', 17482.0),
#  (125, 'California', '8', '   Recreational goods and vehicles', '1997', 25745.5),
#  (126, 'California', '8', '   Other durable goods', '1997', 9922.7),
#  (127, 'California', '8', '  Nondurable goods', '1997', 141852.7),
#  (128, 'California', '8', '   Food and beverages purchased for off-premises consumption', '1997', 54704.4),
#  (129, 'California', '8', '   Clothing and footwear', '1997', 30604.2),
#  (130, 'California', '8', '   Gasoline and other energy goods', '1997', 14604.5),
#  (131, 'California', '8', '   Other nondurable goods', '1997', 41939.5),
#  (132, 'California', '8', ' Services', '1997', 466050.6),
#  (133, 'California', '8', '  Household consumption expenditures (for services)', '1997', 456083.5),
#  (134, 'California', '8', '   Housing and utilities', '1997', 149518.0),
#  (135, 'California', '8', '   Health care', '1997', 93489.3),
#  (136, 'California', '8', '   Transportation services', '1997', 28454.9),
#  (137, 'California', '8', '   Recreation services', '1997', 23827.7),
#  (138, 'California', '8', '   Food services and accommodations', '1997', 43515.9),
#  (139, 'California', '8', '   Financial services and insurance', '1997', 64095.0),
#  (140, 'California', '8', '   Other services', '1997', 53182.6),
#  (141, 'California', '8', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 9967.1),
#  (142, 'California', '8', '   Gross output of nonprofit institutions', '1997', 55721.1),
#  (143, 'California', '8', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 45753.9),
#  (144, 'Colorado', '7', 'Personal consumption expenditures', '1997', 89469.6),
#  (145, 'Colorado', '7', ' Goods', '1997', 31743.4),
#  (146, 'Colorado', '7', '  Durable goods', '1997', 12094.5),
#  (147, 'Colorado', '7', '   Motor vehicles and parts', '1997', 4250.7),
#  (148, 'Colorado', '7', '   Furnishings and durable household equipment', '1997', 3008.0),
#  (149, 'Colorado', '7', '   Recreational goods and vehicles', '1997', 3277.2),
#  (150, 'Colorado', '7', '   Other durable goods', '1997', 1558.6),
#  (151, 'Colorado', '7', '  Nondurable goods', '1997', 19648.8),
#  (152, 'Colorado', '7', '   Food and beverages purchased for off-premises consumption', '1997', 7258.8),
#  (153, 'Colorado', '7', '   Clothing and footwear', '1997', 3720.4),
#  (154, 'Colorado', '7', '   Gasoline and other energy goods', '1997', 2363.1),
#  (155, 'Colorado', '7', '   Other nondurable goods', '1997', 6306.6),
#  (156, 'Colorado', '7', ' Services', '1997', 57726.3),
#  (157, 'Colorado', '7', '  Household consumption expenditures (for services)', '1997', 56809.3),
#  (158, 'Colorado', '7', '   Housing and utilities', '1997', 18934.4),
#  (159, 'Colorado', '7', '   Health care', '1997', 10317.6),
#  (160, 'Colorado', '7', '   Transportation services', '1997', 4538.4),
#  (161, 'Colorado', '7', '   Recreation services', '1997', 3740.5),
#  (162, 'Colorado', '7', '   Food services and accommodations', '1997', 6725.3),
#  (163, 'Colorado', '7', '   Financial services and insurance', '1997', 5889.7),
#  (164, 'Colorado', '7', '   Other services', '1997', 6663.4),
#  (165, 'Colorado', '7', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 917.0),
#  (166, 'Colorado', '7', '   Gross output of nonprofit institutions', '1997', 6775.0),
#  (167, 'Colorado', '7', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 5858.0),
#  (168, 'Connecticut', '1', 'Personal consumption expenditures', '1997', 85205.2),
#  (169, 'Connecticut', '1', ' Goods', '1997', 28806.8),
#  (170, 'Connecticut', '1', '  Durable goods', '1997', 9459.5),
#  (171, 'Connecticut', '1', '   Motor vehicles and parts', '1997', 3664.7),
#  (172, 'Connecticut', '1', '   Furnishings and durable household equipment', '1997', 2189.0),
#  (173, 'Connecticut', '1', '   Recreational goods and vehicles', '1997', 2282.6),
#  (174, 'Connecticut', '1', '   Other durable goods', '1997', 1323.2),
#  (175, 'Connecticut', '1', '  Nondurable goods', '1997', 19347.3),
#  (176, 'Connecticut', '1', '   Food and beverages purchased for off-premises consumption', '1997', 6629.7),
#  (177, 'Connecticut', '1', '   Clothing and footwear', '1997', 3814.9),
#  (178, 'Connecticut', '1', '   Gasoline and other energy goods', '1997', 2354.8),
#  (179, 'Connecticut', '1', '   Other nondurable goods', '1997', 6548.0),
#  (180, 'Connecticut', '1', ' Services', '1997', 56398.3),
#  (181, 'Connecticut', '1', '  Household consumption expenditures (for services)', '1997', 54701.3),
#  (182, 'Connecticut', '1', '   Housing and utilities', '1997', 16780.6),
#  (183, 'Connecticut', '1', '   Health care', '1997', 11944.1),
#  (184, 'Connecticut', '1', '   Transportation services', '1997', 3493.7),
#  (185, 'Connecticut', '1', '   Recreation services', '1997', 2630.8),
#  (186, 'Connecticut', '1', '   Food services and accommodations', '1997', 3982.2),
#  (187, 'Connecticut', '1', '   Financial services and insurance', '1997', 7682.6),
#  (188, 'Connecticut', '1', '   Other services', '1997', 8187.4),
#  (189, 'Connecticut', '1', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 1697.0),
#  (190, 'Connecticut', '1', '   Gross output of nonprofit institutions', '1997', 8531.0),
#  (191, 'Connecticut', '1', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 6834.0),
#  (192, 'Delaware', '2', 'Personal consumption expenditures', '1997', 16225.9),
#  (193, 'Delaware', '2', ' Goods', '1997', 6040.0),
#  (194, 'Delaware', '2', '  Durable goods', '1997', 2477.0),
#  (195, 'Delaware', '2', '   Motor vehicles and parts', '1997', 1057.6),
#  (196, 'Delaware', '2', '   Furnishings and durable household equipment', '1997', 379.6),
#  (197, 'Delaware', '2', '   Recreational goods and vehicles', '1997', 697.8),
#  (198, 'Delaware', '2', '   Other durable goods', '1997', 342.0),
#  (199, 'Delaware', '2', '  Nondurable goods', '1997', 3563.0),
#  (200, 'Delaware', '2', '   Food and beverages purchased for off-premises consumption', '1997', 1573.6),
#  (201, 'Delaware', '2', '   Clothing and footwear', '1997', 718.9),
#  (202, 'Delaware', '2', '   Gasoline and other energy goods', '1997', 372.8),
#  (203, 'Delaware', '2', '   Other nondurable goods', '1997', 897.7),
#  (204, 'Delaware', '2', ' Services', '1997', 10185.9),
#  (205, 'Delaware', '2', '  Household consumption expenditures (for services)', '1997', 9858.9),
#  (206, 'Delaware', '2', '   Housing and utilities', '1997', 2950.5),
#  (207, 'Delaware', '2', '   Health care', '1997', 2290.8),
#  (208, 'Delaware', '2', '   Transportation services', '1997', 549.4),
#  (209, 'Delaware', '2', '   Recreation services', '1997', 605.1),
#  (210, 'Delaware', '2', '   Food services and accommodations', '1997', 1084.3),
#  (211, 'Delaware', '2', '   Financial services and insurance', '1997', 952.8),
#  (212, 'Delaware', '2', '   Other services', '1997', 1426.0),
#  (213, 'Delaware', '2', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 327.0),
#  (214, 'Delaware', '2', '   Gross output of nonprofit institutions', '1997', 1623.0),
#  (215, 'Delaware', '2', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 1296.0),
#  (216, 'District of Columbia', '2', 'Personal consumption expenditures', '1997', 18121.3),
#  (217, 'District of Columbia', '2', ' Goods', '1997', 5163.4),
#  (218, 'District of Columbia', '2', '  Durable goods', '1997', 1663.4),
#  (219, 'District of Columbia', '2', '   Motor vehicles and parts', '1997', 696.9),
#  (220, 'District of Columbia', '2', '   Furnishings and durable household equipment', '1997', 312.5),
#  (221, 'District of Columbia', '2', '   Recreational goods and vehicles', '1997', 379.9),
#  (222, 'District of Columbia', '2', '   Other durable goods', '1997', 274.1),
#  (223, 'District of Columbia', '2', '  Nondurable goods', '1997', 3500.0),
#  (224, 'District of Columbia', '2', '   Food and beverages purchased for off-premises consumption', '1997', 1208.7),
#  (225, 'District of Columbia', '2', '   Clothing and footwear', '1997', 753.0),
#  (226, 'District of Columbia', '2', '   Gasoline and other energy goods', '1997', 568.6),
#  (227, 'District of Columbia', '2', '   Other nondurable goods', '1997', 969.7),
#  (228, 'District of Columbia', '2', ' Services', '1997', 12957.9),
#  (229, 'District of Columbia', '2', '  Household consumption expenditures (for services)', '1997', 12707.9),
#  (230, 'District of Columbia', '2', '   Housing and utilities', '1997', 2615.6),
#  (231, 'District of Columbia', '2', '   Health care', '1997', 2953.8),
#  (232, 'District of Columbia', '2', '   Transportation services', '1997', 581.5),
#  (233, 'District of Columbia', '2', '   Recreation services', '1997', 502.6),
#  (234, 'District of Columbia', '2', '   Food services and accommodations', '1997', 885.3),
#  (235, 'District of Columbia', '2', '   Financial services and insurance', '1997', 1430.4),
#  (236, 'District of Columbia', '2', '   Other services', '1997', 3738.7),
#  (237, 'District of Columbia', '2', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 250.0),
#  (238, 'District of Columbia', '2', '   Gross output of nonprofit institutions', '1997', 1496.0),
#  (239, 'District of Columbia', '2', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 1246.0),
#  (240, 'Florida', '5', 'Personal consumption expenditures', '1997', 314431.2),
#  (241, 'Florida', '5', ' Goods', '1997', 114740.5),
#  (242, 'Florida', '5', '  Durable goods', '1997', 44437.4),
#  (243, 'Florida', '5', '   Motor vehicles and parts', '1997', 18510.9),
#  (244, 'Florida', '5', '   Furnishings and durable household equipment', '1997', 10733.9),
#  (245, 'Florida', '5', '   Recreational goods and vehicles', '1997', 11246.2),
#  (246, 'Florida', '5', '   Other durable goods', '1997', 3946.4),
#  (247, 'Florida', '5', '  Nondurable goods', '1997', 70303.2),
#  (248, 'Florida', '5', '   Food and beverages purchased for off-premises consumption', '1997', 28903.9),
#  (249, 'Florida', '5', '   Clothing and footwear', '1997', 11473.6),
#  (250, 'Florida', '5', '   Gasoline and other energy goods', '1997', 7025.6),
#  (251, 'Florida', '5', '   Other nondurable goods', '1997', 22900.0),
#  (252, 'Florida', '5', ' Services', '1997', 199690.7),
#  (253, 'Florida', '5', '  Household consumption expenditures (for services)', '1997', 199412.6),
#  (254, 'Florida', '5', '   Housing and utilities', '1997', 58094.6),
#  (255, 'Florida', '5', '   Health care', '1997', 46350.6),
#  (256, 'Florida', '5', '   Transportation services', '1997', 10592.5),
#  (257, 'Florida', '5', '   Recreation services', '1997', 10568.3),
#  (258, 'Florida', '5', '   Food services and accommodations', '1997', 24930.0),
#  (259, 'Florida', '5', '   Financial services and insurance', '1997', 23782.0),
#  (260, 'Florida', '5', '   Other services', '1997', 25094.7),
#  (261, 'Florida', '5', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 278.0),
#  (262, 'Florida', '5', '   Gross output of nonprofit institutions', '1997', 16261.0),
#  (263, 'Florida', '5', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 15983.0),
#  (264, 'Georgia', '5', 'Personal consumption expenditures', '1997', 145244.3),
#  (265, 'Georgia', '5', ' Goods', '1997', 58323.1),
#  (266, 'Georgia', '5', '  Durable goods', '1997', 21757.6),
#  (267, 'Georgia', '5', '   Motor vehicles and parts', '1997', 9601.4),
#  (268, 'Georgia', '5', '   Furnishings and durable household equipment', '1997', 5542.9),
#  (269, 'Georgia', '5', '   Recreational goods and vehicles', '1997', 4139.4),
#  (270, 'Georgia', '5', '   Other durable goods', '1997', 2474.0),
#  (271, 'Georgia', '5', '  Nondurable goods', '1997', 36565.4),
#  (272, 'Georgia', '5', '   Food and beverages purchased for off-premises consumption', '1997', 13260.0),
#  (273, 'Georgia', '5', '   Clothing and footwear', '1997', 7335.5),
#  (274, 'Georgia', '5', '   Gasoline and other energy goods', '1997', 4582.4),
#  (275, 'Georgia', '5', '   Other nondurable goods', '1997', 11387.5),
#  (276, 'Georgia', '5', ' Services', '1997', 86921.2),
#  (277, 'Georgia', '5', '  Household consumption expenditures (for services)', '1997', 86424.2),
#  (278, 'Georgia', '5', '   Housing and utilities', '1997', 25673.0),
#  (279, 'Georgia', '5', '   Health care', '1997', 21136.3),
#  (280, 'Georgia', '5', '   Transportation services', '1997', 4112.1),
#  (281, 'Georgia', '5', '   Recreation services', '1997', 4378.6),
#  (282, 'Georgia', '5', '   Food services and accommodations', '1997', 10324.4),
#  (283, 'Georgia', '5', '   Financial services and insurance', '1997', 8877.5),
#  (284, 'Georgia', '5', '   Other services', '1997', 11922.4),
#  (285, 'Georgia', '5', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 497.0),
#  (286, 'Georgia', '5', '   Gross output of nonprofit institutions', '1997', 10659.0),
#  (287, 'Georgia', '5', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 10162.0),
#  (288, 'Hawaii', '8', 'Personal consumption expenditures', '1997', 25888.4),
#  (289, 'Hawaii', '8', ' Goods', '1997', 8877.8),
#  (290, 'Hawaii', '8', '  Durable goods', '1997', 2702.0),
#  (291, 'Hawaii', '8', '   Motor vehicles and parts', '1997', 886.5),
#  (292, 'Hawaii', '8', '   Furnishings and durable household equipment', '1997', 616.1),
#  (293, 'Hawaii', '8', '   Recreational goods and vehicles', '1997', 756.4),
#  (294, 'Hawaii', '8', '   Other durable goods', '1997', 443.0),
#  (295, 'Hawaii', '8', '  Nondurable goods', '1997', 6175.8),
#  (296, 'Hawaii', '8', '   Food and beverages purchased for off-premises consumption', '1997', 2620.5),
#  (297, 'Hawaii', '8', '   Clothing and footwear', '1997', 987.4),
#  (298, 'Hawaii', '8', '   Gasoline and other energy goods', '1997', 515.5),
#  (299, 'Hawaii', '8', '   Other nondurable goods', '1997', 2052.4),
#  (300, 'Hawaii', '8', ' Services', '1997', 17010.6),
#  (301, 'Hawaii', '8', '  Household consumption expenditures (for services)', '1997', 16168.6),
#  (302, 'Hawaii', '8', '   Housing and utilities', '1997', 4739.6),
#  (303, 'Hawaii', '8', '   Health care', '1997', 3826.7),
#  (304, 'Hawaii', '8', '   Transportation services', '1997', 868.7),
#  (305, 'Hawaii', '8', '   Recreation services', '1997', 916.0),
#  (306, 'Hawaii', '8', '   Food services and accommodations', '1997', 1350.6),
#  (307, 'Hawaii', '8', '   Financial services and insurance', '1997', 1817.6),
#  (308, 'Hawaii', '8', '   Other services', '1997', 2649.3),
#  (309, 'Hawaii', '8', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 842.0),
#  (310, 'Hawaii', '8', '   Gross output of nonprofit institutions', '1997', 2701.0),
#  (311, 'Hawaii', '8', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 1859.0),
#  (312, 'Idaho', '7', 'Personal consumption expenditures', '1997', 21121.2),
#  (313, 'Idaho', '7', ' Goods', '1997', 8800.7),
#  (314, 'Idaho', '7', '  Durable goods', '1997', 3412.1),
#  (315, 'Idaho', '7', '   Motor vehicles and parts', '1997', 1546.4),
#  (316, 'Idaho', '7', '   Furnishings and durable household equipment', '1997', 693.3),
#  (317, 'Idaho', '7', '   Recreational goods and vehicles', '1997', 818.2),
#  (318, 'Idaho', '7', '   Other durable goods', '1997', 354.1),
#  (319, 'Idaho', '7', '  Nondurable goods', '1997', 5388.6),
#  (320, 'Idaho', '7', '   Food and beverages purchased for off-premises consumption', '1997', 2285.2),
#  (321, 'Idaho', '7', '   Clothing and footwear', '1997', 773.9),
#  (322, 'Idaho', '7', '   Gasoline and other energy goods', '1997', 819.9),
#  (323, 'Idaho', '7', '   Other nondurable goods', '1997', 1509.6),
#  (324, 'Idaho', '7', ' Services', '1997', 12320.5),
#  (325, 'Idaho', '7', '  Household consumption expenditures (for services)', '1997', 12020.5),
#  (326, 'Idaho', '7', '   Housing and utilities', '1997', 3828.1),
#  (327, 'Idaho', '7', '   Health care', '1997', 2643.6),
#  (328, 'Idaho', '7', '   Transportation services', '1997', 646.1),
#  (329, 'Idaho', '7', '   Recreation services', '1997', 739.5),
#  (330, 'Idaho', '7', '   Food services and accommodations', '1997', 1268.6),
#  (331, 'Idaho', '7', '   Financial services and insurance', '1997', 1530.6),
#  (332, 'Idaho', '7', '   Other services', '1997', 1364.1),
#  (333, 'Idaho', '7', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 300.0),
#  (334, 'Idaho', '7', '   Gross output of nonprofit institutions', '1997', 1925.0),
#  (335, 'Idaho', '7', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 1625.0),
#  (336, 'Illinois', '3', 'Personal consumption expenditures', '1997', 259886.5),
#  (337, 'Illinois', '3', ' Goods', '1997', 89417.9),
#  (338, 'Illinois', '3', '  Durable goods', '1997', 33541.1),
#  (339, 'Illinois', '3', '   Motor vehicles and parts', '1997', 13890.0),
#  (340, 'Illinois', '3', '   Furnishings and durable household equipment', '1997', 7332.8),
#  (341, 'Illinois', '3', '   Recreational goods and vehicles', '1997', 7741.8),
#  (342, 'Illinois', '3', '   Other durable goods', '1997', 4576.4),
#  (343, 'Illinois', '3', '  Nondurable goods', '1997', 55876.8),
#  (344, 'Illinois', '3', '   Food and beverages purchased for off-premises consumption', '1997', 19442.5),
#  (345, 'Illinois', '3', '   Clothing and footwear', '1997', 11939.5),
#  (346, 'Illinois', '3', '   Gasoline and other energy goods', '1997', 5433.0),
#  (347, 'Illinois', '3', '   Other nondurable goods', '1997', 19061.7),
#  (348, 'Illinois', '3', ' Services', '1997', 170468.6),
#  (349, 'Illinois', '3', '  Household consumption expenditures (for services)', '1997', 162050.6),
#  (350, 'Illinois', '3', '   Housing and utilities', '1997', 47820.7),
#  (351, 'Illinois', '3', '   Health care', '1997', 34988.3),
#  (352, 'Illinois', '3', '   Transportation services', '1997', 11441.5),
#  (353, 'Illinois', '3', '   Recreation services', '1997', 9941.6),
#  (354, 'Illinois', '3', '   Food services and accommodations', '1997', 15456.7),
#  (355, 'Illinois', '3', '   Financial services and insurance', '1997', 17476.0),
#  (356, 'Illinois', '3', '   Other services', '1997', 24925.8),
#  (357, 'Illinois', '3', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 8418.1),
#  (358, 'Illinois', '3', '   Gross output of nonprofit institutions', '1997', 30953.0),
#  (359, 'Illinois', '3', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 22535.0),
#  (360, 'Indiana', '3', 'Personal consumption expenditures', '1997', 111212.2),
#  (361, 'Indiana', '3', ' Goods', '1997', 43892.3),
#  (362, 'Indiana', '3', '  Durable goods', '1997', 15570.7),
#  (363, 'Indiana', '3', '   Motor vehicles and parts', '1997', 6883.3),
#  (364, 'Indiana', '3', '   Furnishings and durable household equipment', '1997', 3366.0),
#  (365, 'Indiana', '3', '   Recreational goods and vehicles', '1997', 3560.1),
#  (366, 'Indiana', '3', '   Other durable goods', '1997', 1761.2),
#  (367, 'Indiana', '3', '  Nondurable goods', '1997', 28321.6),
#  (368, 'Indiana', '3', '   Food and beverages purchased for off-premises consumption', '1997', 10714.0),
#  (369, 'Indiana', '3', '   Clothing and footwear', '1997', 4731.5),
#  (370, 'Indiana', '3', '   Gasoline and other energy goods', '1997', 3748.2),
#  (371, 'Indiana', '3', '   Other nondurable goods', '1997', 9127.9),
#  (372, 'Indiana', '3', ' Services', '1997', 67319.9),
#  (373, 'Indiana', '3', '  Household consumption expenditures (for services)', '1997', 64403.9),
#  (374, 'Indiana', '3', '   Housing and utilities', '1997', 18210.6),
#  (375, 'Indiana', '3', '   Health care', '1997', 16019.3),
#  (376, 'Indiana', '3', '   Transportation services', '1997', 4103.1),
#  (377, 'Indiana', '3', '   Recreation services', '1997', 5174.6),
#  (378, 'Indiana', '3', '   Food services and accommodations', '1997', 6878.4),
#  (379, 'Indiana', '3', '   Financial services and insurance', '1997', 5800.3),
#  (380, 'Indiana', '3', '   Other services', '1997', 8217.6),
#  (381, 'Indiana', '3', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 2916.0),
#  (382, 'Indiana', '3', '   Gross output of nonprofit institutions', '1997', 11271.0),
#  (383, 'Indiana', '3', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 8355.0),
#  (384, 'Iowa', '4', 'Personal consumption expenditures', '1997', 53685.2),
#  (385, 'Iowa', '4', ' Goods', '1997', 20810.4),
#  (386, 'Iowa', '4', '  Durable goods', '1997', 7676.9),
#  (387, 'Iowa', '4', '   Motor vehicles and parts', '1997', 3404.0),
#  (388, 'Iowa', '4', '   Furnishings and durable household equipment', '1997', 1568.7),
#  (389, 'Iowa', '4', '   Recreational goods and vehicles', '1997', 1744.2),
#  (390, 'Iowa', '4', '   Other durable goods', '1997', 960.1),
#  (391, 'Iowa', '4', '  Nondurable goods', '1997', 13133.5),
#  (392, 'Iowa', '4', '   Food and beverages purchased for off-premises consumption', '1997', 4672.8),
#  (393, 'Iowa', '4', '   Clothing and footwear', '1997', 2136.0),
#  (394, 'Iowa', '4', '   Gasoline and other energy goods', '1997', 2116.6),
#  (395, 'Iowa', '4', '   Other nondurable goods', '1997', 4208.1),
#  (396, 'Iowa', '4', ' Services', '1997', 32874.8),
#  (397, 'Iowa', '4', '  Household consumption expenditures (for services)', '1997', 31192.7),
#  (398, 'Iowa', '4', '   Housing and utilities', '1997', 8316.3),
#  (399, 'Iowa', '4', '   Health care', '1997', 7799.8),
#  (400, 'Iowa', '4', '   Transportation services', '1997', 1626.2),
#  (401, 'Iowa', '4', '   Recreation services', '1997', 2419.4),
#  (402, 'Iowa', '4', '   Food services and accommodations', '1997', 2982.1),
#  (403, 'Iowa', '4', '   Financial services and insurance', '1997', 3182.9),
#  (404, 'Iowa', '4', '   Other services', '1997', 4866.3),
#  (405, 'Iowa', '4', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 1682.0),
#  (406, 'Iowa', '4', '   Gross output of nonprofit institutions', '1997', 6067.0),
#  (407, 'Iowa', '4', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 4385.0),
#  (408, 'Kansas', '4', 'Personal consumption expenditures', '1997', 47648.9),
#  (409, 'Kansas', '4', ' Goods', '1997', 19252.9),
#  (410, 'Kansas', '4', '  Durable goods', '1997', 6881.2),
#  (411, 'Kansas', '4', '   Motor vehicles and parts', '1997', 2970.3),
#  (412, 'Kansas', '4', '   Furnishings and durable household equipment', '1997', 1425.5),
#  (413, 'Kansas', '4', '   Recreational goods and vehicles', '1997', 1653.0),
#  (414, 'Kansas', '4', '   Other durable goods', '1997', 832.4),
#  (415, 'Kansas', '4', '  Nondurable goods', '1997', 12371.7),
#  (416, 'Kansas', '4', '   Food and beverages purchased for off-premises consumption', '1997', 4773.0),
#  (417, 'Kansas', '4', '   Clothing and footwear', '1997', 1948.4),
#  (418, 'Kansas', '4', '   Gasoline and other energy goods', '1997', 1496.2),
#  (419, 'Kansas', '4', '   Other nondurable goods', '1997', 4154.0),
#  (420, 'Kansas', '4', ' Services', '1997', 28396.0),
#  (421, 'Kansas', '4', '  Household consumption expenditures (for services)', '1997', 27609.0),
#  (422, 'Kansas', '4', '   Housing and utilities', '1997', 8116.8),
#  (423, 'Kansas', '4', '   Health care', '1997', 7339.9),
#  (424, 'Kansas', '4', '   Transportation services', '1997', 1579.1),
#  (425, 'Kansas', '4', '   Recreation services', '1997', 1310.5),
#  (426, 'Kansas', '4', '   Food services and accommodations', '1997', 2906.0),
#  (427, 'Kansas', '4', '   Financial services and insurance', '1997', 2905.8),
#  (428, 'Kansas', '4', '   Other services', '1997', 3450.8),
#  (429, 'Kansas', '4', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 787.0),
#  (430, 'Kansas', '4', '   Gross output of nonprofit institutions', '1997', 4440.0),
#  (431, 'Kansas', '4', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 3653.0),
#  (432, 'Kentucky', '5', 'Personal consumption expenditures', '1997', 67463.0),
#  (433, 'Kentucky', '5', ' Goods', '1997', 27318.5),
#  (434, 'Kentucky', '5', '  Durable goods', '1997', 9171.1),
#  (435, 'Kentucky', '5', '   Motor vehicles and parts', '1997', 4161.9),
#  (436, 'Kentucky', '5', '   Furnishings and durable household equipment', '1997', 2066.1),
#  (437, 'Kentucky', '5', '   Recreational goods and vehicles', '1997', 1942.5),
#  (438, 'Kentucky', '5', '   Other durable goods', '1997', 1000.6),
#  (439, 'Kentucky', '5', '  Nondurable goods', '1997', 18147.4),
#  (440, 'Kentucky', '5', '   Food and beverages purchased for off-premises consumption', '1997', 6773.3),
#  (441, 'Kentucky', '5', '   Clothing and footwear', '1997', 2774.8),
#  (442, 'Kentucky', '5', '   Gasoline and other energy goods', '1997', 2463.3),
#  (443, 'Kentucky', '5', '   Other nondurable goods', '1997', 6136.1),
#  (444, 'Kentucky', '5', ' Services', '1997', 40144.5),
#  (445, 'Kentucky', '5', '  Household consumption expenditures (for services)', '1997', 38666.5),
#  (446, 'Kentucky', '5', '   Housing and utilities', '1997', 10196.3),
#  (447, 'Kentucky', '5', '   Health care', '1997', 11014.0),
#  (448, 'Kentucky', '5', '   Transportation services', '1997', 2063.9),
#  (449, 'Kentucky', '5', '   Recreation services', '1997', 2795.4),
#  (450, 'Kentucky', '5', '   Food services and accommodations', '1997', 4413.2),
#  (451, 'Kentucky', '5', '   Financial services and insurance', '1997', 3864.1),
#  (452, 'Kentucky', '5', '   Other services', '1997', 4319.6),
#  (453, 'Kentucky', '5', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 1478.0),
#  (454, 'Kentucky', '5', '   Gross output of nonprofit institutions', '1997', 6188.0),
#  (455, 'Kentucky', '5', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 4710.0),
#  (456, 'Louisiana', '5', 'Personal consumption expenditures', '1997', 74088.6),
#  (457, 'Louisiana', '5', ' Goods', '1997', 29269.7),
#  (458, 'Louisiana', '5', '  Durable goods', '1997', 10092.8),
#  (459, 'Louisiana', '5', '   Motor vehicles and parts', '1997', 4731.4),
#  (460, 'Louisiana', '5', '   Furnishings and durable household equipment', '1997', 2210.7),
#  (461, 'Louisiana', '5', '   Recreational goods and vehicles', '1997', 2076.3),
#  (462, 'Louisiana', '5', '   Other durable goods', '1997', 1074.4),
#  (463, 'Louisiana', '5', '  Nondurable goods', '1997', 19177.0),
#  (464, 'Louisiana', '5', '   Food and beverages purchased for off-premises consumption', '1997', 7716.3),
#  (465, 'Louisiana', '5', '   Clothing and footwear', '1997', 3278.3),
#  (466, 'Louisiana', '5', '   Gasoline and other energy goods', '1997', 2350.5),
#  (467, 'Louisiana', '5', '   Other nondurable goods', '1997', 5831.9),
#  (468, 'Louisiana', '5', ' Services', '1997', 44818.8),
#  (469, 'Louisiana', '5', '  Household consumption expenditures (for services)', '1997', 43767.8),
#  (470, 'Louisiana', '5', '   Housing and utilities', '1997', 12538.5),
#  (471, 'Louisiana', '5', '   Health care', '1997', 12525.3),
#  (472, 'Louisiana', '5', '   Transportation services', '1997', 2121.8),
#  (473, 'Louisiana', '5', '   Recreation services', '1997', 2599.3),
#  (474, 'Louisiana', '5', '   Food services and accommodations', '1997', 4904.1),
#  (475, 'Louisiana', '5', '   Financial services and insurance', '1997', 4531.5),
#  (476, 'Louisiana', '5', '   Other services', '1997', 4547.2),
#  (477, 'Louisiana', '5', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 1051.0),
#  (478, 'Louisiana', '5', '   Gross output of nonprofit institutions', '1997', 5160.0),
#  (479, 'Louisiana', '5', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 4109.0),
#  (480, 'Maine', '1', 'Personal consumption expenditures', '1997', 25586.7),
#  (481, 'Maine', '1', ' Goods', '1997', 10076.9),
#  (482, 'Maine', '1', '  Durable goods', '1997', 3173.9),
#  (483, 'Maine', '1', '   Motor vehicles and parts', '1997', 1393.8),
#  (484, 'Maine', '1', '   Furnishings and durable household equipment', '1997', 600.3),
#  (485, 'Maine', '1', '   Recreational goods and vehicles', '1997', 767.2),
#  (486, 'Maine', '1', '   Other durable goods', '1997', 412.5),
#  (487, 'Maine', '1', '  Nondurable goods', '1997', 6903.0),
#  (488, 'Maine', '1', '   Food and beverages purchased for off-premises consumption', '1997', 2709.2),
#  (489, 'Maine', '1', '   Clothing and footwear', '1997', 1137.3),
#  (490, 'Maine', '1', '   Gasoline and other energy goods', '1997', 1006.9),
#  (491, 'Maine', '1', '   Other nondurable goods', '1997', 2049.7),
#  (492, 'Maine', '1', ' Services', '1997', 15509.8),
#  (493, 'Maine', '1', '  Household consumption expenditures (for services)', '1997', 14650.8),
#  (494, 'Maine', '1', '   Housing and utilities', '1997', 4073.2),
#  (495, 'Maine', '1', '   Health care', '1997', 3728.0),
#  (496, 'Maine', '1', '   Transportation services', '1997', 626.9),
#  (497, 'Maine', '1', '   Recreation services', '1997', 880.8),
#  (498, 'Maine', '1', '   Food services and accommodations', '1997', 1537.6),
#  (499, 'Maine', '1', '   Financial services and insurance', '1997', 1705.9),
#  (500, 'Maine', '1', '   Other services', '1997', 2098.4),
#  (501, 'Maine', '1', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 859.0),
#  (502, 'Maine', '1', '   Gross output of nonprofit institutions', '1997', 2735.0),
#  (503, 'Maine', '1', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 1876.0),
#  (504, 'Maryland', '2', 'Personal consumption expenditures', '1997', 112122.6),
#  (505, 'Maryland', '2', ' Goods', '1997', 39953.3),
#  (506, 'Maryland', '2', '  Durable goods', '1997', 14148.1),
#  (507, 'Maryland', '2', '   Motor vehicles and parts', '1997', 5804.3),
#  (508, 'Maryland', '2', '   Furnishings and durable household equipment', '1997', 3246.5),
#  (509, 'Maryland', '2', '   Recreational goods and vehicles', '1997', 3377.7),
#  (510, 'Maryland', '2', '   Other durable goods', '1997', 1719.6),
#  (511, 'Maryland', '2', '  Nondurable goods', '1997', 25805.3),
#  (512, 'Maryland', '2', '   Food and beverages purchased for off-premises consumption', '1997', 9305.1),
#  (513, 'Maryland', '2', '   Clothing and footwear', '1997', 5101.1),
#  (514, 'Maryland', '2', '   Gasoline and other energy goods', '1997', 2638.7),
#  (515, 'Maryland', '2', '   Other nondurable goods', '1997', 8760.4),
#  (516, 'Maryland', '2', ' Services', '1997', 72169.2),
#  (517, 'Maryland', '2', '  Household consumption expenditures (for services)', '1997', 70755.2),
#  (518, 'Maryland', '2', '   Housing and utilities', '1997', 23151.6),
#  (519, 'Maryland', '2', '   Health care', '1997', 15638.1),
#  (520, 'Maryland', '2', '   Transportation services', '1997', 3806.0),
#  (521, 'Maryland', '2', '   Recreation services', '1997', 4415.1),
#  (522, 'Maryland', '2', '   Food services and accommodations', '1997', 6553.1),
#  (523, 'Maryland', '2', '   Financial services and insurance', '1997', 7179.9),
#  (524, 'Maryland', '2', '   Other services', '1997', 10011.4),
#  (525, 'Maryland', '2', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 1414.0),
#  (526, 'Maryland', '2', '   Gross output of nonprofit institutions', '1997', 10735.0),
#  (527, 'Maryland', '2', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 9321.0),
#  (528, 'Massachusetts', '1', 'Personal consumption expenditures', '1997', 158943.7),
#  (529, 'Massachusetts', '1', ' Goods', '1997', 53015.5),
#  (530, 'Massachusetts', '1', '  Durable goods', '1997', 18852.5),
#  (531, 'Massachusetts', '1', '   Motor vehicles and parts', '1997', 6247.8),
#  (532, 'Massachusetts', '1', '   Furnishings and durable household equipment', '1997', 3868.1),
#  (533, 'Massachusetts', '1', '   Recreational goods and vehicles', '1997', 5806.8),
#  (534, 'Massachusetts', '1', '   Other durable goods', '1997', 2929.9),
#  (535, 'Massachusetts', '1', '  Nondurable goods', '1997', 34163.0),
#  (536, 'Massachusetts', '1', '   Food and beverages purchased for off-premises consumption', '1997', 12139.8),
#  (537, 'Massachusetts', '1', '   Clothing and footwear', '1997', 7320.0),
#  (538, 'Massachusetts', '1', '   Gasoline and other energy goods', '1997', 3483.1),
#  (539, 'Massachusetts', '1', '   Other nondurable goods', '1997', 11220.1),
#  (540, 'Massachusetts', '1', ' Services', '1997', 105928.2),
#  (541, 'Massachusetts', '1', '  Household consumption expenditures (for services)', '1997', 102419.1),
#  (542, 'Massachusetts', '1', '   Housing and utilities', '1997', 30666.5),
#  (543, 'Massachusetts', '1', '   Health care', '1997', 24550.4),
#  (544, 'Massachusetts', '1', '   Transportation services', '1997', 5323.2),
#  (545, 'Massachusetts', '1', '   Recreation services', '1997', 5697.4),
#  (546, 'Massachusetts', '1', '   Food services and accommodations', '1997', 9700.8),
#  (547, 'Massachusetts', '1', '   Financial services and insurance', '1997', 13510.5),
#  (548, 'Massachusetts', '1', '   Other services', '1997', 12970.5),
#  (549, 'Massachusetts', '1', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 3509.0),
#  (550, 'Massachusetts', '1', '   Gross output of nonprofit institutions', '1997', 14921.0),
#  (551, 'Massachusetts', '1', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 11412.0),
#  (552, 'Michigan', '3', 'Personal consumption expenditures', '1997', 201735.0),
#  (553, 'Michigan', '3', ' Goods', '1997', 73264.3),
#  (554, 'Michigan', '3', '  Durable goods', '1997', 26429.7),
#  (555, 'Michigan', '3', '   Motor vehicles and parts', '1997', 10686.2),
#  (556, 'Michigan', '3', '   Furnishings and durable household equipment', '1997', 6022.4),
#  (557, 'Michigan', '3', '   Recreational goods and vehicles', '1997', 6249.9),
#  (558, 'Michigan', '3', '   Other durable goods', '1997', 3471.2),
#  (559, 'Michigan', '3', '  Nondurable goods', '1997', 46834.6),
#  (560, 'Michigan', '3', '   Food and beverages purchased for off-premises consumption', '1997', 17746.3),
#  (561, 'Michigan', '3', '   Clothing and footwear', '1997', 8634.0),
#  (562, 'Michigan', '3', '   Gasoline and other energy goods', '1997', 5394.2),
#  (563, 'Michigan', '3', '   Other nondurable goods', '1997', 15060.0),
#  (564, 'Michigan', '3', ' Services', '1997', 128470.7),
#  (565, 'Michigan', '3', '  Household consumption expenditures (for services)', '1997', 121929.6),
#  (566, 'Michigan', '3', '   Housing and utilities', '1997', 34137.1),
#  (567, 'Michigan', '3', '   Health care', '1997', 28150.5),
#  (568, 'Michigan', '3', '   Transportation services', '1997', 11518.5),
#  (569, 'Michigan', '3', '   Recreation services', '1997', 9366.4),
#  (570, 'Michigan', '3', '   Food services and accommodations', '1997', 10810.7),
#  (571, 'Michigan', '3', '   Financial services and insurance', '1997', 13717.7),
#  (572, 'Michigan', '3', '   Other services', '1997', 14228.8),
#  (573, 'Michigan', '3', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 6541.0),
#  (574, 'Michigan', '3', '   Gross output of nonprofit institutions', '1997', 23454.0),
#  (575, 'Michigan', '3', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 16913.0),
#  (576, 'Minnesota', '4', 'Personal consumption expenditures', '1997', 108022.3),
#  (577, 'Minnesota', '4', ' Goods', '1997', 38154.3),
#  (578, 'Minnesota', '4', '  Durable goods', '1997', 15119.7),
#  (579, 'Minnesota', '4', '   Motor vehicles and parts', '1997', 5961.2),
#  (580, 'Minnesota', '4', '   Furnishings and durable household equipment', '1997', 3044.0),
#  (581, 'Minnesota', '4', '   Recreational goods and vehicles', '1997', 3601.2),
#  (582, 'Minnesota', '4', '   Other durable goods', '1997', 2513.3),
#  (583, 'Minnesota', '4', '  Nondurable goods', '1997', 23034.6),
#  (584, 'Minnesota', '4', '   Food and beverages purchased for off-premises consumption', '1997', 8687.9),
#  (585, 'Minnesota', '4', '   Clothing and footwear', '1997', 4355.7),
#  (586, 'Minnesota', '4', '   Gasoline and other energy goods', '1997', 3164.9),
#  (587, 'Minnesota', '4', '   Other nondurable goods', '1997', 6826.0),
#  (588, 'Minnesota', '4', ' Services', '1997', 69868.0),
#  (589, 'Minnesota', '4', '  Household consumption expenditures (for services)', '1997', 66872.9),
#  (590, 'Minnesota', '4', '   Housing and utilities', '1997', 17344.8),
#  (591, 'Minnesota', '4', '   Health care', '1997', 16688.7),
#  (592, 'Minnesota', '4', '   Transportation services', '1997', 4927.4),
#  (593, 'Minnesota', '4', '   Recreation services', '1997', 5495.7),
#  (594, 'Minnesota', '4', '   Food services and accommodations', '1997', 5913.1),
#  (595, 'Minnesota', '4', '   Financial services and insurance', '1997', 7592.0),
#  (596, 'Minnesota', '4', '   Other services', '1997', 8911.3),
#  (597, 'Minnesota', '4', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 2995.0),
#  (598, 'Minnesota', '4', '   Gross output of nonprofit institutions', '1997', 11898.0),
#  (599, 'Minnesota', '4', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 8903.0),
#  (600, 'Mississippi', '5', 'Personal consumption expenditures', '1997', 40277.8),
#  (601, 'Mississippi', '5', ' Goods', '1997', 16775.3),
#  (602, 'Mississippi', '5', '  Durable goods', '1997', 5515.2),
#  (603, 'Mississippi', '5', '   Motor vehicles and parts', '1997', 2714.4),
#  (604, 'Mississippi', '5', '   Furnishings and durable household equipment', '1997', 1197.9),
#  (605, 'Mississippi', '5', '   Recreational goods and vehicles', '1997', 1100.2),
#  (606, 'Mississippi', '5', '   Other durable goods', '1997', 502.7),
#  (607, 'Mississippi', '5', '  Nondurable goods', '1997', 11260.1),
#  (608, 'Mississippi', '5', '   Food and beverages purchased for off-premises consumption', '1997', 4454.8),
#  (609, 'Mississippi', '5', '   Clothing and footwear', '1997', 1852.5),
#  (610, 'Mississippi', '5', '   Gasoline and other energy goods', '1997', 1575.0),
#  (611, 'Mississippi', '5', '   Other nondurable goods', '1997', 3377.9),
#  (612, 'Mississippi', '5', ' Services', '1997', 23502.5),
#  (613, 'Mississippi', '5', '  Household consumption expenditures (for services)', '1997', 22980.5),
#  (614, 'Mississippi', '5', '   Housing and utilities', '1997', 6967.1),
# ...
#  (799, 'New York', '2', '  Nondurable goods', '1997', 94154.1),
#  (800, 'New York', '2', '   Food and beverages purchased for off-premises consumption', '1997', 27673.2),
#  (801, 'New York', '2', '   Clothing and footwear', '1997', 22292.2),
#  (802, 'New York', '2', '   Gasoline and other energy goods', '1997', 6925.6),
#  (803, 'New York', '2', '   Other nondurable goods', '1997', 37263.1),
#  (804, 'New York', '2', ' Services', '1997', 284217.5),
#  (805, 'New York', '2', '  Household consumption expenditures (for services)', '1997', 275213.4),
#  (806, 'New York', '2', '   Housing and utilities', '1997', 77204.9),
#  (807, 'New York', '2', '   Health care', '1997', 64620.1),
#  (808, 'New York', '2', '   Transportation services', '1997', 19840.3),
#  (809, 'New York', '2', '   Recreation services', '1997', 15124.3),
#  (810, 'New York', '2', '   Food services and accommodations', '1997', 22954.9),
#  (811, 'New York', '2', '   Financial services and insurance', '1997', 30462.0),
#  (812, 'New York', '2', '   Other services', '1997', 45006.9),
#  (813, 'New York', '2', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 9004.1),
#  (814, 'New York', '2', '   Gross output of nonprofit institutions', '1997', 44038.0),
#  (815, 'New York', '2', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 35034.0),
#  (816, 'North Carolina', '5', 'Personal consumption expenditures', '1997', 139107.8),
#  (817, 'North Carolina', '5', ' Goods', '1997', 57727.9),
#  (818, 'North Carolina', '5', '  Durable goods', '1997', 21673.0),
#  (819, 'North Carolina', '5', '   Motor vehicles and parts', '1997', 9528.4),
#  (820, 'North Carolina', '5', '   Furnishings and durable household equipment', '1997', 5277.5),
#  (821, 'North Carolina', '5', '   Recreational goods and vehicles', '1997', 4551.8),
#  (822, 'North Carolina', '5', '   Other durable goods', '1997', 2315.3),
#  (823, 'North Carolina', '5', '  Nondurable goods', '1997', 36054.9),
#  (824, 'North Carolina', '5', '   Food and beverages purchased for off-premises consumption', '1997', 13711.2),
#  (825, 'North Carolina', '5', '   Clothing and footwear', '1997', 6603.6),
#  (826, 'North Carolina', '5', '   Gasoline and other energy goods', '1997', 4576.9),
#  (827, 'North Carolina', '5', '   Other nondurable goods', '1997', 11163.2),
#  (828, 'North Carolina', '5', ' Services', '1997', 81379.9),
#  (829, 'North Carolina', '5', '  Household consumption expenditures (for services)', '1997', 79508.9),
#  (830, 'North Carolina', '5', '   Housing and utilities', '1997', 22929.0),
#  (831, 'North Carolina', '5', '   Health care', '1997', 20330.9),
#  (832, 'North Carolina', '5', '   Transportation services', '1997', 3554.9),
#  (833, 'North Carolina', '5', '   Recreation services', '1997', 4769.9),
#  (834, 'North Carolina', '5', '   Food services and accommodations', '1997', 8936.1),
#  (835, 'North Carolina', '5', '   Financial services and insurance', '1997', 9294.2),
#  (836, 'North Carolina', '5', '   Other services', '1997', 9694.0),
#  (837, 'North Carolina', '5', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 1871.0),
#  (838, 'North Carolina', '5', '   Gross output of nonprofit institutions', '1997', 9183.0),
#  (839, 'North Carolina', '5', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 7312.0),
#  (840, 'North Dakota', '4', 'Personal consumption expenditures', '1997', 12084.8),
#  (841, 'North Dakota', '4', ' Goods', '1997', 4988.6),
#  (842, 'North Dakota', '4', '  Durable goods', '1997', 1930.7),
#  (843, 'North Dakota', '4', '   Motor vehicles and parts', '1997', 859.9),
#  (844, 'North Dakota', '4', '   Furnishings and durable household equipment', '1997', 397.6),
#  (845, 'North Dakota', '4', '   Recreational goods and vehicles', '1997', 453.2),
#  (846, 'North Dakota', '4', '   Other durable goods', '1997', 220.1),
#  (847, 'North Dakota', '4', '  Nondurable goods', '1997', 3057.9),
#  (848, 'North Dakota', '4', '   Food and beverages purchased for off-premises consumption', '1997', 1092.9),
#  (849, 'North Dakota', '4', '   Clothing and footwear', '1997', 546.3),
#  (850, 'North Dakota', '4', '   Gasoline and other energy goods', '1997', 555.9),
#  (851, 'North Dakota', '4', '   Other nondurable goods', '1997', 862.8),
#  (852, 'North Dakota', '4', ' Services', '1997', 7096.2),
#  (853, 'North Dakota', '4', '  Household consumption expenditures (for services)', '1997', 6753.2),
#  (854, 'North Dakota', '4', '   Housing and utilities', '1997', 1623.8),
#  (855, 'North Dakota', '4', '   Health care', '1997', 1926.8),
#  (856, 'North Dakota', '4', '   Transportation services', '1997', 369.4),
#  (857, 'North Dakota', '4', '   Recreation services', '1997', 498.1),
#  (858, 'North Dakota', '4', '   Food services and accommodations', '1997', 724.9),
#  (859, 'North Dakota', '4', '   Financial services and insurance', '1997', 689.8),
#  (860, 'North Dakota', '4', '   Other services', '1997', 920.3),
#  (861, 'North Dakota', '4', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 343.0),
#  (862, 'North Dakota', '4', '   Gross output of nonprofit institutions', '1997', 1129.0),
#  (863, 'North Dakota', '4', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 786.0),
#  (864, 'Ohio', '3', 'Personal consumption expenditures', '1997', 219818.0),
#  (865, 'Ohio', '3', ' Goods', '1997', 82438.9),
#  (866, 'Ohio', '3', '  Durable goods', '1997', 29776.8),
#  (867, 'Ohio', '3', '   Motor vehicles and parts', '1997', 13184.5),
#  (868, 'Ohio', '3', '   Furnishings and durable household equipment', '1997', 6805.8),
#  (869, 'Ohio', '3', '   Recreational goods and vehicles', '1997', 6190.0),
#  (870, 'Ohio', '3', '   Other durable goods', '1997', 3596.5),
#  (871, 'Ohio', '3', '  Nondurable goods', '1997', 52662.1),
#  (872, 'Ohio', '3', '   Food and beverages purchased for off-premises consumption', '1997', 19477.8),
#  (873, 'Ohio', '3', '   Clothing and footwear', '1997', 9346.0),
#  (874, 'Ohio', '3', '   Gasoline and other energy goods', '1997', 5787.4),
#  (875, 'Ohio', '3', '   Other nondurable goods', '1997', 18050.9),
#  (876, 'Ohio', '3', ' Services', '1997', 137379.1),
#  (877, 'Ohio', '3', '  Household consumption expenditures (for services)', '1997', 130863.0),
#  (878, 'Ohio', '3', '   Housing and utilities', '1997', 35460.1),
#  (879, 'Ohio', '3', '   Health care', '1997', 32665.2),
#  (880, 'Ohio', '3', '   Transportation services', '1997', 9352.4),
#  (881, 'Ohio', '3', '   Recreation services', '1997', 9835.2),
#  (882, 'Ohio', '3', '   Food services and accommodations', '1997', 13785.5),
#  (883, 'Ohio', '3', '   Financial services and insurance', '1997', 13542.6),
#  (884, 'Ohio', '3', '   Other services', '1997', 16222.0),
#  (885, 'Ohio', '3', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 6516.0),
#  (886, 'Ohio', '3', '   Gross output of nonprofit institutions', '1997', 23238.0),
#  (887, 'Ohio', '3', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 16722.0),
#  (888, 'Oklahoma', '6', 'Personal consumption expenditures', '1997', 54661.9),
#  (889, 'Oklahoma', '6', ' Goods', '1997', 22388.2),
#  (890, 'Oklahoma', '6', '  Durable goods', '1997', 8476.0),
#  (891, 'Oklahoma', '6', '   Motor vehicles and parts', '1997', 4103.3),
#  (892, 'Oklahoma', '6', '   Furnishings and durable household equipment', '1997', 1644.7),
#  (893, 'Oklahoma', '6', '   Recreational goods and vehicles', '1997', 1792.2),
#  (894, 'Oklahoma', '6', '   Other durable goods', '1997', 935.8),
#  (895, 'Oklahoma', '6', '  Nondurable goods', '1997', 13912.2),
#  (896, 'Oklahoma', '6', '   Food and beverages purchased for off-premises consumption', '1997', 5007.4),
#  (897, 'Oklahoma', '6', '   Clothing and footwear', '1997', 2500.4),
#  (898, 'Oklahoma', '6', '   Gasoline and other energy goods', '1997', 2092.9),
#  (899, 'Oklahoma', '6', '   Other nondurable goods', '1997', 4311.5),
#  (900, 'Oklahoma', '6', ' Services', '1997', 32273.8),
#  (901, 'Oklahoma', '6', '  Household consumption expenditures (for services)', '1997', 31600.8),
#  (902, 'Oklahoma', '6', '   Housing and utilities', '1997', 8959.7),
#  (903, 'Oklahoma', '6', '   Health care', '1997', 8549.5),
#  (904, 'Oklahoma', '6', '   Transportation services', '1997', 1286.7),
#  (905, 'Oklahoma', '6', '   Recreation services', '1997', 2229.7),
#  (906, 'Oklahoma', '6', '   Food services and accommodations', '1997', 3387.6),
#  (907, 'Oklahoma', '6', '   Financial services and insurance', '1997', 3084.8),
#  (908, 'Oklahoma', '6', '   Other services', '1997', 4102.8),
#  (909, 'Oklahoma', '6', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 673.0),
#  (910, 'Oklahoma', '6', '   Gross output of nonprofit institutions', '1997', 4748.0),
#  (911, 'Oklahoma', '6', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 4075.0),
#  (912, 'Oregon', '8', 'Personal consumption expenditures', '1997', 69028.6),
#  (913, 'Oregon', '8', ' Goods', '1997', 25865.0),
#  (914, 'Oregon', '8', '  Durable goods', '1997', 9683.8),
#  (915, 'Oregon', '8', '   Motor vehicles and parts', '1997', 4022.6),
#  (916, 'Oregon', '8', '   Furnishings and durable household equipment', '1997', 2240.6),
#  (917, 'Oregon', '8', '   Recreational goods and vehicles', '1997', 2545.0),
#  (918, 'Oregon', '8', '   Other durable goods', '1997', 875.6),
#  (919, 'Oregon', '8', '  Nondurable goods', '1997', 16181.2),
#  (920, 'Oregon', '8', '   Food and beverages purchased for off-premises consumption', '1997', 6444.8),
#  (921, 'Oregon', '8', '   Clothing and footwear', '1997', 2940.2),
#  (922, 'Oregon', '8', '   Gasoline and other energy goods', '1997', 2018.1),
#  (923, 'Oregon', '8', '   Other nondurable goods', '1997', 4778.1),
#  (924, 'Oregon', '8', ' Services', '1997', 43163.6),
#  (925, 'Oregon', '8', '  Household consumption expenditures (for services)', '1997', 41879.6),
#  (926, 'Oregon', '8', '   Housing and utilities', '1997', 13725.6),
#  (927, 'Oregon', '8', '   Health care', '1997', 8110.7),
#  (928, 'Oregon', '8', '   Transportation services', '1997', 2720.9),
#  (929, 'Oregon', '8', '   Recreation services', '1997', 3213.1),
#  (930, 'Oregon', '8', '   Food services and accommodations', '1997', 4481.4),
#  (931, 'Oregon', '8', '   Financial services and insurance', '1997', 4869.6),
#  (932, 'Oregon', '8', '   Other services', '1997', 4758.4),
#  (933, 'Oregon', '8', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 1284.0),
#  (934, 'Oregon', '8', '   Gross output of nonprofit institutions', '1997', 6028.0),
#  (935, 'Oregon', '8', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 4744.0),
#  (936, 'Pennsylvania', '2', 'Personal consumption expenditures', '1997', 250125.4),
#  (937, 'Pennsylvania', '2', ' Goods', '1997', 87737.9),
#  (938, 'Pennsylvania', '2', '  Durable goods', '1997', 30527.5),
#  (939, 'Pennsylvania', '2', '   Motor vehicles and parts', '1997', 12820.5),
#  (940, 'Pennsylvania', '2', '   Furnishings and durable household equipment', '1997', 6746.0),
#  (941, 'Pennsylvania', '2', '   Recreational goods and vehicles', '1997', 7156.4),
#  (942, 'Pennsylvania', '2', '   Other durable goods', '1997', 3804.6),
#  (943, 'Pennsylvania', '2', '  Nondurable goods', '1997', 57210.4),
#  (944, 'Pennsylvania', '2', '   Food and beverages purchased for off-premises consumption', '1997', 20911.8),
#  (945, 'Pennsylvania', '2', '   Clothing and footwear', '1997', 10983.6),
#  (946, 'Pennsylvania', '2', '   Gasoline and other energy goods', '1997', 6337.2),
#  (947, 'Pennsylvania', '2', '   Other nondurable goods', '1997', 18977.8),
#  (948, 'Pennsylvania', '2', ' Services', '1997', 162387.5),
#  (949, 'Pennsylvania', '2', '  Household consumption expenditures (for services)', '1997', 154728.4),
#  (950, 'Pennsylvania', '2', '   Housing and utilities', '1997', 39256.8),
#  (951, 'Pennsylvania', '2', '   Health care', '1997', 38887.7),
#  (952, 'Pennsylvania', '2', '   Transportation services', '1997', 9738.3),
#  (953, 'Pennsylvania', '2', '   Recreation services', '1997', 10653.5),
#  (954, 'Pennsylvania', '2', '   Food services and accommodations', '1997', 13642.5),
#  (955, 'Pennsylvania', '2', '   Financial services and insurance', '1997', 20522.9),
#  (956, 'Pennsylvania', '2', '   Other services', '1997', 22026.9),
#  (957, 'Pennsylvania', '2', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 7659.1),
#  (958, 'Pennsylvania', '2', '   Gross output of nonprofit institutions', '1997', 27713.0),
#  (959, 'Pennsylvania', '2', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 20054.0),
#  (960, 'Rhode Island', '1', 'Personal consumption expenditures', '1997', 20605.1),
#  (961, 'Rhode Island', '1', ' Goods', '1997', 6404.6),
#  (962, 'Rhode Island', '1', '  Durable goods', '1997', 1835.4),
#  (963, 'Rhode Island', '1', '   Motor vehicles and parts', '1997', 749.5),
#  (964, 'Rhode Island', '1', '   Furnishings and durable household equipment', '1997', 405.3),
#  (965, 'Rhode Island', '1', '   Recreational goods and vehicles', '1997', 437.4),
#  (966, 'Rhode Island', '1', '   Other durable goods', '1997', 243.2),
#  (967, 'Rhode Island', '1', '  Nondurable goods', '1997', 4569.1),
#  (968, 'Rhode Island', '1', '   Food and beverages purchased for off-premises consumption', '1997', 1707.6),
#  (969, 'Rhode Island', '1', '   Clothing and footwear', '1997', 761.2),
#  (970, 'Rhode Island', '1', '   Gasoline and other energy goods', '1997', 534.2),
#  (971, 'Rhode Island', '1', '   Other nondurable goods', '1997', 1566.2),
#  (972, 'Rhode Island', '1', ' Services', '1997', 14200.5),
#  (973, 'Rhode Island', '1', '  Household consumption expenditures (for services)', '1997', 13473.5),
#  (974, 'Rhode Island', '1', '   Housing and utilities', '1997', 4067.5),
#  (975, 'Rhode Island', '1', '   Health care', '1997', 3521.0),
#  (976, 'Rhode Island', '1', '   Transportation services', '1997', 589.5),
#  (977, 'Rhode Island', '1', '   Recreation services', '1997', 699.5),
#  (978, 'Rhode Island', '1', '   Food services and accommodations', '1997', 1340.9),
#  (979, 'Rhode Island', '1', '   Financial services and insurance', '1997', 1328.9),
#  (980, 'Rhode Island', '1', '   Other services', '1997', 1926.3),
#  (981, 'Rhode Island', '1', '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)', '1997', 727.0),
#  (982, 'Rhode Island', '1', '   Gross output of nonprofit institutions', '1997', 2400.0),
#  (983, 'Rhode Island', '1', '   Less: Receipts from sales of goods and services by nonprofit institutions', '1997', 1673.0),
#  (984, 'South Carolina', '5', 'Personal consumption expenditures', '1997', 66902.6),
#  (985, 'South Carolina', '5', ' Goods', '1997', 27197.1),
#  (986, 'South Carolina', '5', '  Durable goods', '1997', 9295.9),
#  (987, 'South Carolina', '5', '   Motor vehicles and parts', '1997', 4147.8),
#  (988, 'South Carolina', '5', '   Furnishings and durable household equipment', '1997', 2199.3),
#  (989, 'South Carolina', '5', '   Recreational goods and vehicles', '1997', 1897.5),
#  (990, 'South Carolina', '5', '   Other durable goods', '1997', 1051.4),
#  (991, 'South Carolina', '5', '  Nondurable goods', '1997', 17901.2),
#  (992, 'South Carolina', '5', '   Food and beverages purchased for off-premises consumption', '1997', 6772.8),
#  (993, 'South Carolina', '5', '   Clothing and footwear', '1997', 3561.7),
#  (994, 'South Carolina', '5', '   Gasoline and other energy goods', '1997', 2439.7),
#  (995, 'South Carolina', '5', '   Other nondurable goods', '1997', 5127.0),
#  (996, 'South Carolina', '5', ' Services', '1997', 39705.5),
#  (997, 'South Carolina', '5', '  Household consumption expenditures (for services)', '1997', 38885.4),
#  (998, 'South Carolina', '5', '   Housing and utilities', '1997', 10881.0),
#  (999, 'South Carolina', '5', '   Health care', '1997', 9772.0),
#  ...]
