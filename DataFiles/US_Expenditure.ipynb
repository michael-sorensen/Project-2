# %%
import pandas as pd
from sqlalchemy import create_engine
import pprint
import psycopg2

# %%
# Import CSV files
csvfile = "DataFiles/SAEXP1.csv"
us_expenditures = pd.read_csv(csvfile)

# %%
us_expenditures.columns
# Out:
# Index(['GeoFIPS', 'GeoName', 'Region', 'TableName', 'LineCode',
#        'IndustryClassification', 'Description', 'Unit', '1997', '1998', '1999',
#        '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
#        '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
#        '2018', '2019'],
#       dtype='object')

# %%
# Get rid of unnecessary columns
us_expendit2 = us_expenditures_df[['GeoFIPS', 'GeoName', 'Region', 'Description', 'Unit', '1997', '1998', '1999',
       '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008',
       '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017',
       '2018', '2019']].copy()

# %%
us_expendit2[us_expenditures_df['GeoName'].notna()]
# Out:
#        GeoFIPS        GeoName Region  \
# 0      "00000"  United States
# 1      "00000"  United States
# 2      "00000"  United States
# 3      "00000"  United States
# 4      "00000"  United States
# ...        ...            ...    ...
# 1435   "98000"       Far West      8
# 1436   "98000"       Far West      8
# 1437   "98000"       Far West      8
# 1438   "98000"       Far West      8
# 1439   "98000"       Far West      8
#
#                                             Description  \
# 0                     Personal consumption expenditures
# 1                                                 Goods
# 2                                         Durable goods
# 3                              Motor vehicles and parts
# 4           Furnishings and durable household equipment
# ...                                                 ...
# 1435                   Financial services and insurance
# 1436                                     Other services
# ...

# %%
# List of categories - 25 categories
description = us_expenditures_df['Description'].unique()
description
# Out:
# array(['Personal consumption expenditures', ' Goods', '  Durable goods',
#        '   Motor vehicles and parts',
#        '   Furnishings and durable household equipment',
#        '   Recreational goods and vehicles', '   Other durable goods',
#        '  Nondurable goods',
#        '   Food and beverages purchased for off-premises consumption',
#        '   Clothing and footwear', '   Gasoline and other energy goods',
#        '   Other nondurable goods', ' Services',
#        '  Household consumption expenditures (for services)',
#        '   Housing and utilities', '   Health care',
#        '   Transportation services', '   Recreation services',
#        '   Food services and accommodations',
#        '   Financial services and insurance', '   Other services',
#        '  Final consumption expenditures of nonprofit institutions serving households (NPISHs)',
#        '   Gross output of nonprofit institutions',
# ...

# %%
#connection = engine.connect()
engine = create_engine('sqlite:///DataFiles/SAEXP1', echo=False)

# %%
# save data into sqlite
us_expendit2.to_sql('us_expenditures', con=engine, if_exists='replace')

# %%
engine.execute("SELECT * FROM us_expenditures").fetchall()
# Out:
# [(0, ' "00000"', 'United States', ' ', 'Personal consumption expenditures', 'Millions of current dollars', 5534091.8, 5874285.0, 6275655.2, 6758605.7, 7061876.3, 7338427.6, 7717658.4, 8206825.4, 8741177.6, 9253947.4, 9699133.5, 9968412.9, 9833212.0, 10177464.5, 10631511.2, 10997927.0, 11309307.3, 11814798.4, 12290166.3, 12762930.6, 13333393.5, 13982899.0, 14533254.0),
#  (1, ' "00000"', 'United States', ' ', ' Goods', 'Millions of current dollars', 2003807.2, 2105476.2, 2283638.6, 2449633.7, 2521835.1, 2594546.2, 2717146.9, 2896184.3, 3076982.5, 3233258.1, 3359733.4, 3355303.7, 3171025.7, 3309453.5, 3508522.9, 3628852.0, 3722069.7, 3855001.8, 3915678.3, 3991320.6, 4165294.4, 4361471.7, 4500860.9),
# ...
